# %%
import pandas as pd

# %%
df = pd.read_csv("len_sweep_results.csv")
print(df.groupby(["model", "context_len_tokens"])["correct"].mean())
# Out:
# model            context_len_tokens
# qwen3-235b-a22b  4096                  1.0
#                  8192                  1.0
#                  16384                 1.0
#                  32768                 1.0
# qwen3-30b-a3b    4096                  1.0
#                  8192                  1.0
#                  16384                 1.0
#                  32768                 1.0
# qwen3-4b         4096                  1.0
#                  8192                  1.0
#                  16384                 1.0
#                  32768                 1.0
# Name: correct, dtype: float64
